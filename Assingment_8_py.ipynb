# %% [markdown]
# #### 1. Is the Python Standard Library included with PyInputPlus?

# %% [markdown]
# - Ans: PyInputPlus is not a part of the Python Standard Library, we must install it separately using Pip.

# %% [markdown]
# #### 2. Why is PyInputPlus commonly imported with import pyinputplus as pypi?

# %% [markdown]
# - Ans: We can import the module with import pyinputplus as pyip so that we can enter a shorter name when calling the module’s functions

# %% [markdown]
# #### 3. How do you distinguish between inputInt() and inputFloat()?

# %% [markdown]
# - Ans: The difference is in the data-type when we use inputInt() the program expects an integer value as input but in inputFloat() it expects a float value i.e number containing a decimal

# %% [markdown]
# #### 4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?

# %% [markdown]
# - Ans: By using pyip.inputint(min=0, max=99)

# %% [markdown]
# #### 5. What is transferred to the keyword arguments allowRegexes and blockRegexes?

# %% [markdown]
# - Ans: A list of regex strings that are either explicitly allowed or denied

# %% [markdown]
# #### 6. If a blank input is entered three times, what does inputStr(limit=3) do?

# %% [markdown]
# - Ans: The function will raise RetryLimitException.

# %% [markdown]
# #### 7. If blank input is entered three times, what does inputStr(limit=3, default=&#39;hello&#39;) do?

# %% [markdown]
# - Ans: The function returns the value 'hello'
